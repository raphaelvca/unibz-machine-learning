# %% [markdown]
# # Advanced Topics in Machine Learning 2021/22 Notebooks
#
# *Welcome!*
#
# ## Lecture Notes
#
# Accompanying code of the lectures:
#
# - Lecture 03:
#     - [Vectorisation](notebooks/1_MLP_DNN/Lecture_02_Vectorisation.ipynb)
#     - [Logistic Regression with Neural Network Mindset](notebooks/1_MLP_DNN/Lecture_02_Logistic_Regression_as_Neural_Network.ipynb) | [Solution](notebooks/1_MLP_DNN/Lecture_02_Sol_Logistic_Regression_as_Neural_Network.ipynb)
# - Lecture 04: [Multi-Layer Perceptron with one hidden layer](notebooks/1_MLP_DNN/Lecture_04_Planar_data_classification_with_onehidden_layer.ipynb)  | [Solution](notebooks/1_MLP_DNN/Lecture_04_Sol_Planar_data_classification_with_onehidden_layer.ipynb)
# - Lecture 06: [Feed Forward Neural Networks in Keras](notebooks/1_MLP_DNN/Lecture_06_Deep_Learning_Keras.ipynb) | [Solution](notebooks/1_MLP_DNN/Lecture_06_Sol_Deep_Learning_Keras.ipynb)
# - Lecture 07: [Training Deep Neural Networks - Initialisation and Batch-Normalisation](notebooks/2_Training/Lecture07_training_deep_neural_networks.ipynb)
# - Lecture 08: [Training Deep Neural Networks - L2 Regularisation and Dropout](notebooks/2_Training/Lecture08_Regularization.ipynb) | [Solution](notebooks/2_Training/Lecture08_Sol_Regularization.ipynb)
# - Lecture 09: [Training Deep Neural Networks - Mini-Batch Gradient Descent](notebooks/2_Training/Lecture09_Mini_Batch_Gradient_Descent.ipynb) | [Solution](notebooks/2_Training/Lecture09_Sol_Mini_Batch_Gradient_Descent.ipynb)
# - Lecture 12: [Convolutional Neural Networks with Keras](notebooks/3_CNNs/Lecture12_CNNs_Keras.ipynb) | [Solution](notebooks/3_CNN/notebooks/3_CNNs/Lecture12_Sol_CNNs_Keras.ipynb)
# - Lecture 14: [Pre-trained Convolutional Neural Networks in Keras](notebooks/3_CNNs/Lecture14_Pretrained_CNNs_Keras.ipynb)
# - Lecture 14 (Tutorial by Boyuan):
#     - [Tensorflow tutorial on transfer learning](https://www.tensorflow.org/tutorials/images/transfer_learning)
#     - [Transfer learning: CNN, ResNet, VGG16, IceptionV3](https://www.kaggle.com/janvichokshi/transfer-learning-cnn-resnet-vgg16-iceptionv3)
#     - [Intel image classification - Fine Tuning VGG16](https://www.kaggle.com/flygirl/intel-image-classification-90-fine-tuning-vgg16)
# - Lecture 15:
#     - [YOLO TensorFlow v2 implementation](https://github.com/zzh8829/yolov3-tf2)
#     - [YOLO TensorFlow v2 Colab](https://colab.research.google.com/github/zzh8829/yolov3-tf2/blob/master/colab_gpu.ipynb)
#     - [Semantic Segmentation implementation](https://github.com/tensorflow/models/tree/master/research/deeplab)
#     - [Semantic Segmentation Colab](https://colab.research.google.com/github/dhassault/tf-semantic-example/blob/master/01b_semantic_segmentation_basic_colab.ipynb)
# - Lecture 17:
#     - [Char-level language model in Keras](notebooks/4_Sequence/Lecture17_Char_RNN.ipynb)
#     - [Sentiment Analysis Embeddings](notebooks/4_Sequence/Lecture17_Sentiment_Analysis_Embeddings.ipynb)
# - Lecture 19: [Autoencoders and Generative Adversarial Networks](notebooks/5_GANs/Lecture19_Autoencoders_and_GANs.ipynb)
# - Lecture 20:
#     - [Deep Convolutional GANs](notebooks/5_GANs/Lecture20_Deep_Convolutional_GANs.ipynb)
#     - [Conditional GANs](notebooks/5_GANs/Lecture20_Conditional_GANs.ipynb)
#
# ## Labs
#
# Accompanying code of the labs:
#
# - Lab01: [Practising with Numpy](notebooks/1_MLP_DNN/Lab01_Python_Basics_With_Numpy.ipynb)
# - Lab02 - GPU cluster:
#     - [Jupyter Notebook](notebooks/1_MLP_DNN/Lab02_Keras_FashionMNIST_Classifier.ipynb)
#     - [Python](notebooks/1_MLP_DNN/Lab02_Keras_FashionMNIST_Classifier.py)
#     - [Sbatch script](notebooks/1_MLP_DNN/script.sh)
# - Lab03: [Initialisation](notebooks/2_Training/Lab03_Initialization.ipynb) | [Solution](notebooks/2_Training/Lab03_Sol_Initialization.ipynb)
# - Lab05: [Convolution model Step by Step](notebooks/3_CNNs/Lab05_Convolution_model_Step_by_Step.ipynb) | [Solution](notebooks/3_CNNs/Lab05_Sol_Convolution_model_Step_by_Step.ipynb)
# <!-- - Lab06: [Neural Style Transfer Tutorial](notebooks/3_CNNs/Lab06_Neural_Style_Transfer.ipynb) -->
# - Lab07:
#     - [Building a Recurrent Neural Network (Python)](notebooks/4_Sequence/Lab07_Building_a_Recurrent_Neural_Network.ipynb)
#     - [RNNs in Keras](notebooks/4_Sequence/Lab07_RNNs_in_Keras.ipynb)
# - Lab08:
#     - [Building a Character level language_model (Python)](notebooks/4_Sequence/Lab08_Character_level_language_model.ipynb) | [Solution](notebooks/4_Sequence/Lab08_Sol_Character_level_language_model.ipynb)
#     - [Machine Translation in Keras](notebooks/4_Sequence/Lab08_Machine_Translation.ipynb) [Solution](notebooks/4_Sequence/Lab08_Sol_Machine_Translation.ipynb)
# - Lab09: [MNIST GAN - Learn to generate MNIST digits](notebooks/5_GANs/Lab09_Generate_MNIST_digits.ipynb)
#
#
# ## Home Assignments
#
# Home assignments are to be delivered in branches (studentID) of the gitlab `code` repository of the course [https://gitlab.inf.unibz.it/atml202122/code](https://gitlab.inf.unibz.it/atml202122/code).
#
# - Home Assignment 01 (Assigned on 19/10/2021 - Due by 02/11/2021):
#     - [Building your Deep Neural Network](notebooks/1_MLP_DNN/HW1_Building_your_Deep_Neural_Network.ipynb) | [Solution](notebooks/1_MLP_DNN/HW1_Sol_Building_your_Deep_Neural_Network.ipynb)
#     - [Deep Neural Network Application (Optional)](notebooks/1_MLP_DNN/HW1_Part2_Deep_Neural_Network_Application.ipynb) | [Solution](notebooks/1_MLP_DNN/HW1_Part2_Sol_Deep_Neural_Network_Application.ipynb)
#
# - Home Assignment 02 (Assigned on 03/11/2021 - Due by 24/11/2021):
#     - [Optimization Method](notebooks/2_Training/HW02_Optimization_methods.ipynb) | [Solution](notebooks/2_Training/HW02_Sol_Optimization_methods.ipynb)
#
# - Home Assignment 03 (Assigned on 17/11/2021 - Due by 08/12/2021):
#     - [Pretrained CNN](notebooks/3_CNNs/HW03_Pretrained_CNNs_Keras.ipynb)
#
# - Home Assignment 04 (Assigned on 07/12/2021 - Due by 22/12/2021):
#     - [Building a RNN in Python](notebooks/4_Sequence/HW04_Building_a_Recurrent_Neural_Network.ipynb)
#
# - Home Assignment 05 (Assigned on 22/12/2021 - Due by 09/01/2022):
#     - [Deep Convolutional GANs to Generate MNIST digits](notebooks/5_GANs/HW05_DCGAN_Generate_MNIST_digits.ipynb)
#
# ## Extra Material
#
# ### Scientific Python tutorials
# - [NumPy](notebooks/extras/tools_numpy.ipynb)
# - [Matplotlib](notebooks/extras/tools_matplotlib.ipynb)
# - [Pandas](notebooks/extras/tools_pandas.ipynb)
#
# ### Math Tutorials
# - [Linear Algebra](notebooks/extras/math_linear_algebra.ipynb)
# - [Differential Calculus](notebooks/extras/math_differential_calculus.ipynb)
